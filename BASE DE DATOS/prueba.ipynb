-- %% [markdown]
-- # [prueba]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [prueba]    Script Date: 21/11/2022 8:47:32 p. m. ******/
CREATE DATABASE [prueba]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'prueba', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\prueba.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'prueba_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\prueba_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [prueba] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [prueba].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [prueba] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [prueba] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [prueba] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [prueba] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [prueba] SET ARITHABORT OFF 
GO
ALTER DATABASE [prueba] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [prueba] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [prueba] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [prueba] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [prueba] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [prueba] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [prueba] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [prueba] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [prueba] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [prueba] SET  ENABLE_BROKER 
GO
ALTER DATABASE [prueba] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [prueba] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [prueba] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [prueba] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [prueba] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [prueba] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [prueba] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [prueba] SET RECOVERY FULL 
GO
ALTER DATABASE [prueba] SET  MULTI_USER 
GO
ALTER DATABASE [prueba] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [prueba] SET DB_CHAINING OFF 
GO
ALTER DATABASE [prueba] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [prueba] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [prueba] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [prueba] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'prueba', N'ON'
GO
ALTER DATABASE [prueba] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[gestion_hospital]

-- %%
USE [prueba]
GO

-- %%
/****** Object:  Table [dbo].[gestion_hospital]    Script Date: 21/11/2022 8:47:32 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[gestion_hospital](
	[id_hospitalizacion] [int] IDENTITY(1,1) NOT NULL,
	[tipo_documento_pa] [char](4) NOT NULL,
	[no_documento_pa] [char](12) NOT NULL,
	[cod_hospital] [int] NULL,
	[fecha_de_ingreso] [date] NULL,
	[fecha_de_salida] [date] NULL,
	[fecha_de_creacion] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_hospitalizacion] ASC,
	[tipo_documento_pa] ASC,
	[no_documento_pa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[hospitales]

-- %%
/****** Object:  Table [dbo].[hospitales]    Script Date: 21/11/2022 8:47:32 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[hospitales](
	[cod_hospital] [int] NOT NULL,
	[nombre_hospital] [nvarchar](30) NULL,
 CONSTRAINT [PK_ID_UNICA] PRIMARY KEY CLUSTERED 
(
	[cod_hospital] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[pacientes]

-- %%
/****** Object:  Table [dbo].[pacientes]    Script Date: 21/11/2022 8:47:32 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[pacientes](
	[tipo_documento] [char](4) NOT NULL,
	[no_documento] [char](12) NOT NULL,
	[nombres] [char](30) NULL,
	[apellidos] [char](30) NULL,
	[fecha_de_nacimiento] [date] NULL,
	[email] [varchar](40) NULL,
PRIMARY KEY CLUSTERED 
(
	[no_documento] ASC,
	[tipo_documento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[gestion_hospital]

-- %%
SET IDENTITY_INSERT [dbo].[gestion_hospital] ON 
INSERT [dbo].[gestion_hospital] ([id_hospitalizacion], [tipo_documento_pa], [no_documento_pa], [cod_hospital], [fecha_de_ingreso], [fecha_de_salida], [fecha_de_creacion]) VALUES (7, N'TI  ', N'1104934879  ', 1234, CAST(N'2022-11-18' AS Date), CAST(N'2022-11-28' AS Date), CAST(N'2022-11-18T00:00:00.000' AS DateTime))
SET IDENTITY_INSERT [dbo].[gestion_hospital] OFF
GO

-- %% [markdown]
-- # [dbo].[hospitales]

-- %%
INSERT [dbo].[hospitales] ([cod_hospital], [nombre_hospital]) VALUES (1234, N'MEDELLIN                      ')
INSERT [dbo].[hospitales] ([cod_hospital], [nombre_hospital]) VALUES (3213, N'cambio                        ')
INSERT [dbo].[hospitales] ([cod_hospital], [nombre_hospital]) VALUES (3423, N'fggggggggggg                  ')
INSERT [dbo].[hospitales] ([cod_hospital], [nombre_hospital]) VALUES (5555, N'IBAGUE                        ')
INSERT [dbo].[hospitales] ([cod_hospital], [nombre_hospital]) VALUES (5678, N'TOLIMA                        ')
INSERT [dbo].[hospitales] ([cod_hospital], [nombre_hospital]) VALUES (9999, N'fggggggggggg                  ')
GO

-- %% [markdown]
-- # [dbo].[pacientes]

-- %%
INSERT [dbo].[pacientes] ([tipo_documento], [no_documento], [nombres], [apellidos], [fecha_de_nacimiento], [email]) VALUES (N'CC  ', N'1104934879  ', N'SEBASTIAN                     ', N'GARCIA                        ', CAST(N'2004-03-17' AS Date), N'jsgarcia978@misena.edu.co')
INSERT [dbo].[pacientes] ([tipo_documento], [no_documento], [nombres], [apellidos], [fecha_de_nacimiento], [email]) VALUES (N'NIP ', N'1104934879  ', N'SEBASTIAN                     ', N'GARCIA                        ', CAST(N'2004-03-17' AS Date), N'jsgarcia978@gmail.com')
INSERT [dbo].[pacientes] ([tipo_documento], [no_documento], [nombres], [apellidos], [fecha_de_nacimiento], [email]) VALUES (N'TI  ', N'1104934879  ', N'SEBASTIAN                     ', N'GARCIA                        ', CAST(N'2004-03-17' AS Date), N'jsgarcia978@misena.edu.co')
GO

-- %% [markdown]
-- # [FK_gestion_hospital_hospitales]

-- %%
ALTER TABLE [dbo].[gestion_hospital]  WITH CHECK ADD  CONSTRAINT [FK_gestion_hospital_hospitales] FOREIGN KEY([cod_hospital])
REFERENCES [dbo].[hospitales] ([cod_hospital])
GO
ALTER TABLE [dbo].[gestion_hospital] CHECK CONSTRAINT [FK_gestion_hospital_hospitales]
GO

-- %% [markdown]
-- # [FK_gestion_hospital_pacientes]

-- %%
ALTER TABLE [dbo].[gestion_hospital]  WITH CHECK ADD  CONSTRAINT [FK_gestion_hospital_pacientes] FOREIGN KEY([no_documento_pa], [tipo_documento_pa])
REFERENCES [dbo].[pacientes] ([no_documento], [tipo_documento])
GO
ALTER TABLE [dbo].[gestion_hospital] CHECK CONSTRAINT [FK_gestion_hospital_pacientes]
GO

-- %% [markdown]
-- # [prueba]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [prueba] SET  READ_WRITE 
GO
